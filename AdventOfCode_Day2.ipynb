# %% [markdown]
# # Advent of Code
# ## Day 2
# ### Task 1
# https://adventofcode.com/2020/day/2
#
# Problem:
# >To try to debug the problem, they have created a list (your puzzle input) of passwords (according to the corrupted database) and the corporate policy when that password was set.
# >
# >For example, suppose you have the following list:
# >
# >1-3 a: abcde
# >1-3 b: cdefg
# >2-9 c: ccccccccc
# >Each line gives the password policy and then the password. The password policy indicates the lowest and highest number of times a given letter must appear for the password to be valid. For example, 1-3 a means that the password must contain a at least 1 time and at most 3 times.
# >
# >In the above example, 2 passwords are valid. The middle password, cdefg, is not; it contains no instances of b, but needs at least 1. The first and third passwords are valid: they contain one a or nine c, both within the limits of their respective policies.
# >
# >How many passwords are valid according to their policies?

# %%
input_data_path = "data/day2_input"

# %%
with open(input_data_path) as f:
    data = [x.replace("\n","") for x in f.readlines()]

# %%
def count_letter_occurrences(letter, string):
    counter = 0
    for char in string:
        if char == letter:
            counter += 1
    return counter

def preprocess_line(input_line):
    minimum = eval(input_line.split("-")[0])
    maximum = eval(input_line.split("-")[1].split(" ")[0])
    letter = input_line.split(" ")[1].split(":")[0]
    string = input_line.split(" ")[-1]
    return (minimum, maximum, letter, string)

# %%
def test_preprocess_line(input_line="1-12 w: zwwzwwwswwwwwwwwww"):
    return preprocess_line(input_line) == (1, 12, "w", "zwwzwwwswwwwwwwwww")

# %%
test_preprocess_line()
# Out:
# True

# %%
valid_passwords = []

for i, line in enumerate(data):
    minimum, maximum, letter, string = preprocess_line(line)
    if minimum <= count_letter_occurrences(letter, string) <= maximum:
        valid_passwords.append((i, string))

# %%
valid_passwords
# Out:
# [(0, 'dnjjrtclnzdnghnbnn'),
#  (1, 'rrrrcqr'),
#  (3, 'spppppppppppvp'),
#  (4, 'xfwxxxxx'),
#  (5, 'nnnnsnnnnnnnnnnnnnnn'),
#  (6, 'zvzhbp'),
#  (7, 'ddddhd'),
#  (8, 'jjjjjjjjjjjtdrjjgj'),
#  (9, 'tppqpppppppppcpspppp'),
#  (11, 'lqzdzqfz'),
#  (12, 'nssssssslsssslshssx'),
#  (14, 'wfjtzbzzjtjwm'),
#  (16, 'glltvgdngllzlllplrlh'),
#  (18, 'ggggggggggzggb'),
#  (20, 'ffffffffmffffzfffwf'),
#  (21, 'fgggzggmggggzmg'),
#  (22, 'kbkkwthmc'),
#  (24, 'kxxx'),
#  (25, 'rrrrrcrwkr'),
#  (26, 'gxgqggkfgggfg'),
#  (27, 'xxgxx'),
#  (28, 'ddzczddd'),
#  (29, 'fflffffffvrffflwfv'),
#  (31, 'fnmjmmmmhmjtm'),
#  (32, 'nnnxnnnnnnnnnnnh'),
#  (33, 'xhhhhhlhhhhhhhhjhhh'),
#  (34, 'hhgvpg'),
#  (36, 'khkkkknkkknkk'),
#  (39, 'zzzzzzz'),
#  (40, 'jfjqjjjjjjjjs'),
#  (41, 'vdmxclfpmmhmmgdffd'),
#  (46, 'qqqqqqqmqqlq'),
#  (48, 'bnvfbbbpbbbsnwrbb'),
#  (49, 'hjllblkl'),
#  (51, 'jmjjjjjfjjjjjj'),
#  (52, 'zvhhhzzxqzgzjqz'),
#  (53, 'zqqzflzdckzztf'),
#  (56, 'bbbbbb'),
#  (60, 'pjlsksssdssss'),
# ...

# %%
#How many passwords are valid according to their policies?

len(valid_passwords)
# Out:
# 622

# %% [markdown]
# ## Task 2
# >Each policy actually describes two positions in the password, where 1 means the first character, 2 means the second character, and so on. (Be careful; Toboggan Corporate Policies have no concept of "index zero"!) Exactly one of these positions must contain the given letter. Other occurrences of the letter are irrelevant for the purposes of policy enforcement.
# >
# >Given the same example list from above:
# >
# >1-3 a: abcde is valid: position 1 contains a and position 3 does not.
# >1-3 b: cdefg is invalid: neither position 1 nor position 3 contains b.
# >2-9 c: ccccccccc is invalid: both position 2 and position 9 contain c.
# >How many passwords are valid according to the new interpretation of the policies?

# %%
task2_valid_passwords = []

for i, line in enumerate(data):
    minimum, maximum, letter, string = preprocess_line(line)
    if bool(string[minimum-1]==letter) ^ bool(string[maximum-1]==letter):
        task2_valid_passwords.append((i, string))

# %%
len(task2_valid_passwords)
# Out:
# 263
